# %% [markdown]
# ## 483hw3_VisApp.ipynb (Fall 2026)
# ### Your own application code (Part 3): train a [4, 7, 3] network on Iris and visualize the training curves.
# #### Complete the Setup section on the assignment page first, and make sure `483hw3_Check1.ipynb` and `483hw3_Check2.ipynb` both run cleanly before starting this file.

# %%
# %load_ext autoreload
# %autoreload 2

# import the class Network from "network.py"
import network
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the dataset (same split as Check1/Check2)
iris_data = network.my_load_csv('iris-3.csv', 4, 3)
iris_train = iris_data[:105]
iris_test = iris_data[105:]

# %%
# Create a new network of size [4, 7, 3] with random initial weights
net1 = network.Network([4, 7, 3])

# TODO: train net1 on iris_train/iris_test (up to 100 epochs, mini-batch size 8;
# try a few learning rates starting around 0.5 until you see 'interesting' results),
# collect the returned training/validation result lists, and use them to plot
# accuracy, MSE, CE, and LL (training vs. validation) as described on the
# assignment page.
